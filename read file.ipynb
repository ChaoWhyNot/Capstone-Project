# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_excel('/Users/jianchaohuo/Downloads/raw data.xlsx')
df
# Out:
#         a         b  Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5  Unnamed: 6
# 0   76.85     62.24         NaN         NaN        NaN        NaN         NaN  \
# 1   77.06     57.93         NaN         NaN        NaN        NaN         NaN
# 2   77.33     67.79         NaN         NaN        NaN        NaN         NaN
# 3     NaN       NaN         NaN         NaN        NaN        NaN         NaN
# 4     NaN         a         NaN         NaN        NaN          b         NaN
# 5      cp         1    1.000000    1.000000          1   1.125507    0.596630
# 6      cd  1.305156    1.119868    1.341479    1.48949    2.04331    1.198945
# 7     NaN       NaN         NaN         NaN        NaN        NaN         NaN
# 8      CP         1    1.000000    1.000000          1   0.781584    0.205672
# 9      CD  0.621541    0.792195    0.498650   0.637462   0.849566    0.739815
# 10    NaN       NaN         NaN         NaN        NaN        NaN         NaN
# ...

# %%
df.shape
# Out:
# (12, 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 1 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   The Human Fertility Database  9 non-null      object
# dtypes: object(1)
# memory usage: 228.0+ bytes

# %%
boar_sperm = pd.read_csv('/Users/jianchaohuo/Downloads/sperm.csv', sep=',')
boar_sperm
# Out:
#        Area    VCL   VSL   VAP   LIN   STR   WOB  ALH   BCF     Boar
# 0       7.9   17.9   7.2  10.4  40.1  68.8  58.3  1.0   3.0   Boar 1  \
# 1      30.5    NaN   NaN   NaN   NaN   NaN   NaN  NaN   NaN   Boar 1
# 2      27.7  122.9  31.2  54.1  25.4  57.7  44.0  4.0   7.5   Boar 1
# 3      12.1    NaN   NaN   NaN   NaN   NaN   NaN  NaN   NaN   Boar 1
# 4      18.0   53.0  18.5  42.0  34.9  44.0  79.2  2.6   8.0   Boar 1
# ...     ...    ...   ...   ...   ...   ...   ...  ...   ...      ...
# 98015  37.5   73.4  15.8  33.8  21.5  46.7  46.0  3.6  10.0  Boar 17
# 98016  35.2   76.4  17.5  38.7  22.9  45.3  50.6  3.6  10.9  Boar 17
# 98017  30.7   75.1  25.3  33.4  33.7  75.8  44.5  3.4  14.0  Boar 17
# 98018  31.6   50.5  26.3  30.9  52.0  85.1  61.1  3.0   9.1  Boar 17
# 98019  32.5    NaN   NaN   NaN   NaN   NaN   NaN  NaN   NaN  Boar 17
#
#        Ejaculate   K  mK    effect
# 0           1001   1   1  Negative
# 1           1001   0   0       NaN
# ...

# %%
boar_sperm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98020 entries, 0 to 98019
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Area       98020 non-null  float64
#  1   VCL        69170 non-null  float64
#  2   VSL        69170 non-null  float64
#  3   VAP        69170 non-null  float64
#  4   LIN        69170 non-null  float64
#  5   STR        69170 non-null  float64
#  6   WOB        69170 non-null  float64
#  7   ALH        69170 non-null  float64
#  8   BCF        69170 non-null  float64
#  9   Boar       98020 non-null  object
#  10  Ejaculate  98020 non-null  int64
#  11  K          98020 non-null  int64
#  12  mK         98020 non-null  int64
#  13  effect     69170 non-null  object
# dtypes: float64(9), int64(3), object(2)
# memory usage: 10.5+ MB

# %%
fraud = pd.read_csv('/Users/jianchaohuo/Downloads/creditcard.csv', sep=',')
fraud
# Out:
#             Time         V1         V2        V3        V4        V5
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321  \
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22
# ...

# %%
female_fluid = pd.read_csv('/Users/jianchaohuo/Downloads/Female reproductive fluids ‘rescue’ sperm from phenotypic ageing in an external fertilizer/Hadlow_et_al_2023_Female_reproductive_fluids.csv', sep=',')
female_fluid
# Out:
#     analysis_time  date  egg_pool    animal_id  spawn_time  motility_time
# 0      1:39:20 PM  1407         1  1407101.1.S          15            197  \
# 1      1:43:31 PM  1407         1  1407101.1.E          15            202
# 2      1:47:02 PM  1407         1  1407102.1.E          19            205
# 3      1:50:07 PM  1407         1  1407102.1.S          19            208
# 4      1:53:25 PM  1407         1  1407103.1.S          19            211
# ..            ...   ...       ...          ...         ...            ...
# 339    7:12:20 PM  3007         7  3007103.4.S          13            499
# 340    7:16:45 PM  3007         7  3007105.4.S          16            504
# 341    7:20:49 PM  3007         7  3007105.4.E          16            508
# 342    7:27:18 PM  3007         7  3007110.4.E          26            514
# 343    7:33:42 PM  3007         7  3007110.4.S          26            521
#
#      motile_count  motile_mean_alh  motile_mean_bcf  motile_mean_lin
# ...

# %%
female_fluid.isna().sum()
# Out:
# analysis_time              0
# date                       0
# egg_pool                   0
# animal_id                  0
# spawn_time                 0
# motility_time              0
# motile_count               0
# motile_mean_alh            0
# motile_mean_bcf            0
# motile_mean_lin            0
# motile_mean_str            0
# motile_mean_vap            0
# motile_mean_vcl            0
# motile_mean_vsl            0
# motile_mean_wob            0
# motile_percent_of_total    0
# total_count                0
# dtype: int64

# %%
female_fluid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   analysis_time            344 non-null    object
#  1   date                     344 non-null    int64
#  2   egg_pool                 344 non-null    int64
#  3   animal_id                344 non-null    object
#  4   spawn_time               344 non-null    int64
#  5   motility_time            344 non-null    int64
#  6   motile_count             344 non-null    int64
#  7   motile_mean_alh          344 non-null    float64
#  8   motile_mean_bcf          344 non-null    float64
#  9   motile_mean_lin          344 non-null    float64
#  10  motile_mean_str          344 non-null    float64
#  11  motile_mean_vap          344 non-null    float64
#  12  motile_mean_vcl          344 non-null    float64
#  13  motile_mean_vsl          344 non-null    float64
# ...

# %%
female_fluid.describe().T
# Out:
#                          count         mean         std          min
# date                     344.0  2232.581395  546.002925  1407.000000  \
# egg_pool                 344.0     3.883721    1.946327     1.000000
# spawn_time               344.0    26.395349   15.165004     7.000000
# motility_time            344.0   358.950581   91.348213   179.000000
# motile_count             344.0   179.232558   41.622537    53.000000
# motile_mean_alh          344.0     6.566950    1.589769     2.997497
# motile_mean_bcf          344.0    25.605181    6.212363     9.116748
# motile_mean_lin          344.0    45.154502    9.170297    25.405037
# motile_mean_str          344.0    67.933139    9.281670    34.131606
# motile_mean_vap          344.0    77.803905   19.633222    37.375834
# motile_mean_vcl          344.0   114.246376   18.503186    74.995810
# motile_mean_vsl          344.0    51.756981   15.167557    23.423759
# motile_mean_wob          344.0    66.350266   10.249157    46.033407
# ...

# %%
fertility = pd.read_csv('/Users/jianchaohuo/Downloads/fertility.csv', sep=',')
fertility
# Out:
#     Season  Age Childish diseases Accident or serious trauma
# 0   spring   30                no                        yes  \
# 1   spring   35               yes                         no
# 2   spring   27               yes                         no
# 3   spring   32                no                        yes
# 4   spring   30               yes                        yes
# ..     ...  ...               ...                        ...
# 95  winter   30               yes                         no
# 96  winter   29               yes                         no
# 97  winter   30               yes                        yes
# 98  winter   30               yes                         no
# 99  winter   30                no                        yes
#
#    Surgical intervention High fevers in the last year
# 0                    yes       more than 3 months ago  \
# 1                    yes       more than 3 months ago
# 2                     no       more than 3 months ago
# ...

# %%
fertility.shape
# Out:
# (100, 10)

# %%
fertility.columns
# Out:
# Index(['Season', 'Age', 'Childish diseases', 'Accident or serious trauma',
#        'Surgical intervention', 'High fevers in the last year',
#        'Frequency of alcohol consumption', 'Smoking habit',
#        'Number of hours spent sitting per day', 'Diagnosis'],
#       dtype='object')

# %%
a = pd.read_excel('/Users/jianchaohuo/Downloads/medicines_output_medicines_en.xlsx')
a
# Out:
#      Content type:     Medicine
# 0              NaN          NaN  \
# 1              NaN          NaN
# 2              NaN          NaN
# 3              NaN          NaN
# 4              NaN          NaN
# ...            ...          ...
# 2528         Human     Liprolog
# 2529         Human      EchoGen
# 2530         Human    Ecokinase
# 2531         Human     Primavax
# 2532         Human  Pylori-Chek
#
#      Output automatically generated from content on www.ema.europa.eu on:
# 0                                                   NaN                    \
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2528                                    EMEA/H/C/000143
# 2529                                    EMEA/H/C/000149
# ...

# %%
fer = pd.read_excel('/Users/jianchaohuo/Downloads/Fertile_Man_2020.xlsx')
fer
# Out:
#               PI Semen Volume (ml) Sperm Concentration (106/ml)
# 0     Aboutorabi               3.2                           27  \
# 1     Aboutorabi               0.8                          136
# 2     Aboutorabi                 2                           71
# 3     Aboutorabi                 1                           35
# 4     Aboutorabi                 2                           46
# ...          ...               ...                          ...
# 3584        Tang               1.7                           23
# 3585        Tang               2.5                          110
# 3586        Tang                 2                          109
# 3587        Tang               6.2                           96
# 3588        Tang                 3                           36
#
#      Total Number (106) Total Motility (%) Progressive Motility (%)
# 0                  86.4                 35                       20  \
# ...

# %%
fer.shape
# Out:
# (3589, 10)

# %%
fer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3589 entries, 0 to 3588
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   PI                            3589 non-null   object
#  1   Semen Volume (ml)             3589 non-null   object
#  2   Sperm Concentration (106/ml)  3589 non-null   object
#  3   Total Number (106)            3589 non-null   object
#  4   Total Motility (%)            3589 non-null   object
#  5   Progressive Motility (%)      3589 non-null   object
#  6   Non-progressive Motility (%)  3589 non-null   object
#  7   Immotile Spermatozoa (%)      3589 non-null   object
#  8   Vitality (%)                  3589 non-null   object
#  9   Normal Forms (%)              3589 non-null   object
# dtypes: object(10)
# memory usage: 280.5+ KB

# %%
fer.columns
# Out:
# Index(['PI', 'Semen Volume (ml)', 'Sperm Concentration (106/ml)',
#        'Total Number (106)', 'Total Motility (%)', 'Progressive Motility (%)',
#        'Non-progressive Motility (%)', 'Immotile Spermatozoa (%)',
#        'Vitality (%)', 'Normal Forms (%)'],
#       dtype='object')

# %%
fer['PI'].value_counts()
# Out:
# PI
# Tang          1200
# Auger          826
# Swan           487
# Zedan          240
# Baker          206
# Jensen         199
# Aboutorabi     168
# Lotti          105
# Haugen          82
# Evgeni          76
# Name: count, dtype: int64
